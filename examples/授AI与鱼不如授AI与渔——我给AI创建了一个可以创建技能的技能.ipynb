# %%
import shlex
import subprocess
from pathlib import Path
from typing import Callable
from dotenv import load_dotenv
from skills_ref import to_prompt
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain.messages import SystemMessage
from langchain_core.messages import HumanMessage
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse

load_dotenv()
# Out:
# True

# %%
# 自定义可靠的 Shell 工具
@tool
def run_shell(command: str) -> str:
    """执行 shell 命令。command 参数是一个字符串，可以包含空格和特殊字符。"""
    import subprocess
    try:
        result = subprocess.run(
            command,
            shell=True,
            capture_output=True,
            text=True,
            timeout=30
        )
        output = result.stdout if result.returncode == 0 else result.stderr
        return output if output else f"命令执行完成 (返回码: {result.returncode})"
    except Exception as e:
        return f"执行错误: {str(e)}"

# %%
@tool
def get_skill_instruction(skill_name: str) -> str:
    """获取指定技能的详细指令及脚本清单。"""
    base = Path("./skills") / skill_name
    file = base / "SKILL.md"

    if not file.exists():
        return f"错误：找不到技能 {skill_name}"

    content = file.read_text(encoding="utf-8")
    body = content.split("---")[-1].strip()

    scripts = [f.name for f in (base / "scripts").glob("*") if f.is_file()]
    script_info = f"\n\n📂 **可用脚本**: {', '.join(scripts)}" if scripts else "\n\n📂 **可用脚本**: 无"

    return (
        f"# {skill_name} 详情\n"
        f"📍 **技能路径**: `{base}`\n\n"
        f"{body}"
        f"{script_info}"
    )


@wrap_model_call
def add_context(
        request: ModelRequest,
        handler: Callable[[ModelRequest], ModelResponse],
) -> ModelResponse:
    skills_root = Path("./skills")
    skill_paths = [p for p in skills_root.iterdir() if p.is_dir() and (p / "SKILL.md").exists()]
    skills_catalog = to_prompt(skill_paths)
    system_prompt = f"""
# Role
你是一个功能强大的通用人工智能助手。为了更高效、精准地完成复杂任务，你拥有访问“专用技能库”的权限。

# 技能目录 (Skill Catalog)
以下是你当前可以调用的扩展技能列表。每个技能包含名称和核心功能简述：

{skills_catalog}

# 核心操作逻辑 (Operating Logic)
当你处理用户请求时，请遵循以下决策流程：

1. **意图匹配**：判断用户需求是否落在上述 [技能目录] 的覆盖范围内。
2. **按需检索**：如果你决定使用某个技能，**严禁凭经验盲目猜测其操作细节**。你必须立即调用工具 `get_skill_instruction(skill_name)` 来获取该技能的“详细操作手册”。
3. **知识利用**：
    - 阅读手册中提供的执行步骤、参数规范及约束条件。
    - 如果手册中提到需要运行特定的脚本（通常位于 `skills/技能名/scripts/`），请严格按照说明执行对应的命令行操作。
4. **组合执行**：你可以根据任务复杂度，依次检索并利用多个技能来构建完整的解决方案。

# 行为约束
- **先读后做**：在未获取详细指令前，不得尝试调用该技能目录下的任何脚本或文件。
- **路径感知**：使用相对于当前工作目录的完整路径。
- **结果导向**：利用技能解决问题后，简洁反馈结果。
"""
    system_message = SystemMessage(content=system_prompt)
    return handler(request.override(system_message=system_message))


agent = create_agent(ChatOpenAI(model="qwen3-max"), tools=[get_skill_instruction, run_shell],
                     middleware=[add_context])

# %%
from IPython.display import Image, display

display(Image(agent.get_graph().draw_mermaid_png()))

# %%
user_query = "帮我构建一个查看日期、星期、时间的工具。"

inputs = {"messages": [HumanMessage(content=user_query)]}

for output in agent.stream(inputs, config={"recursion_limit": 50}, stream_mode="values"):
    output["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# 帮我构建一个查看日期、星期、时间的工具。
# ================================== Ai Message ==================================
# Tool Calls:
#   get_skill_instruction (call_312ed5b2919d4c9a8b20b590)
#  Call ID: call_312ed5b2919d4c9a8b20b590
#   Args:
#     skill_name: skill-creator
# ================================= Tool Message =================================
# Name: get_skill_instruction
#
# # skill-creator 详情
# 📍 **技能路径**: `skills/skill-creator`
#
# ` 开头，包含 name 和 description
#
# ## 失败排查
#
# 如果看到 `SKILL.md must start with YAML frontmatter` 错误，说明 frontmatter 缺失！
#
# 📂 **可用脚本**: 无
# ================================== Ai Message ==================================
# Tool Calls:
#   run_shell (call_46e82fd53023437280879a8d)
#  Call ID: call_46e82fd53023437280879a8d
#   Args:
#     command: mkdir -p skills/date-time-viewer
# ================================= Tool Message =================================
# Name: run_shell
#
# 命令执行完成 (返回码: 0)
# ================================== Ai Message ==================================
# Tool Calls:
#   run_shell (call_2c7f44ea31c541189f1b7f89)
#  Call ID: call_2c7f44ea31c541189f1b7f89
#   Args:
#     command: cat > skills/date-time-viewer/SKILL.md << 'EOF'
# ---
# name: date-time-viewer
# description: 一个用于查看当前日期、星期和时间的工具。
# ---
#
# 此技能提供一个简单的命令行工具，用于显示格式化的当前日期和时间信息。
# EOF
# ================================= Tool Message =================================
# Name: run_shell
#
# 命令执行完成 (返回码: 0)
# ================================== Ai Message ==================================
# Tool Calls:
#   run_shell (call_303780e0bcdc4546978ebddb)
#  Call ID: call_303780e0bcdc4546978ebddb
#   Args:
#     command: mkdir -p skills/date-time-viewer/scripts
# ================================= Tool Message =================================
# Name: run_shell
#
# 命令执行完成 (返回码: 0)
# ================================== Ai Message ==================================
# Tool Calls:
#   run_shell (call_7e8667e7f88a4722a8b36f32)
#  Call ID: call_7e8667e7f88a4722a8b36f32
#   Args:
#     command: cat > skills/date-time-viewer/scripts/view_date_time.sh << 'EOF'
# #!/bin/bash
# # 查看当前日期、星期和时间
# echo "当前日期和时间："
# date +"%Y年%m月%d日 %A %H:%M:%S"
# EOF
# ================================= Tool Message =================================
# Name: run_shell
#
# 命令执行完成 (返回码: 0)
# ================================== Ai Message ==================================
# Tool Calls:
#   run_shell (call_8597fc2000f144808e338dca)
#  Call ID: call_8597fc2000f144808e338dca
#   Args:
#     command: chmod +x skills/date-time-viewer/scripts/view_date_time.sh
# ================================= Tool Message =================================
# Name: run_shell
#
# 命令执行完成 (返回码: 0)
# ================================== Ai Message ==================================
#
# 已成功为您构建了查看日期、星期和时间的工具。该工具位于 `skills/date-time-viewer/` 目录下。
#
# 您可以直接运行以下命令来使用它：
# ```bash
# ./skills/date-time-viewer/scripts/view_date_time.sh
# ```

# %%
user_query = "现在是什么时间，星期几？"

inputs = {"messages": [HumanMessage(content=user_query)]}

for output in agent.stream(inputs, config={"recursion_limit": 50}, stream_mode="values"):
    output["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# 现在是什么时间，星期几？
# ================================== Ai Message ==================================
# Tool Calls:
#   get_skill_instruction (call_e19a7290d4284e40a6cf16b4)
#  Call ID: call_e19a7290d4284e40a6cf16b4
#   Args:
#     skill_name: date-time-viewer
# ================================= Tool Message =================================
# Name: get_skill_instruction
#
# # date-time-viewer 详情
# 📍 **技能路径**: `skills/date-time-viewer`
#
# 此技能提供一个简单的命令行工具，用于显示格式化的当前日期和时间信息。
#
# 📂 **可用脚本**: view_date_time.sh
# ================================== Ai Message ==================================
# Tool Calls:
#   run_shell (call_315ca249cf0f4f9486ccb336)
#  Call ID: call_315ca249cf0f4f9486ccb336
#   Args:
#     command: skills/date-time-viewer/view_date_time.sh
# ================================= Tool Message =================================
# Name: run_shell
#
# /bin/sh: skills/date-time-viewer/view_date_time.sh: No such file or directory
#
# ================================== Ai Message ==================================
#
# 看起来技能文件路径存在问题，让我检查一下当前目录结构，确认脚本是否存在。
# Tool Calls:
#   run_shell (call_11461b672bbb4f05b7e0be8f)
#  Call ID: call_11461b672bbb4f05b7e0be8f
#   Args:
#     command: ls -l /Users/zhengjie/Documents/learn-langchain/examples/skills/date-time-viewer/
# ================================= Tool Message =================================
# Name: run_shell
#
# total 8
# -rw-r--r--@ 1 zhengjie  staff  209 Mar 12 21:48 SKILL.md
# drwxr-xr-x@ 3 zhengjie  staff   96 Mar 12 21:48 scripts
#
# ================================== Ai Message ==================================
#
# 我看到脚本在 `scripts` 目录下，让我查看该目录内容并执行正确的脚本。
# Tool Calls:
#   run_shell (call_907a1f57bf1f469d95e37c5c)
#  Call ID: call_907a1f57bf1f469d95e37c5c
#   Args:
#     command: ls -l /Users/zhengjie/Documents/learn-langchain/examples/skills/date-time-viewer/scripts/
# ================================= Tool Message =================================
# Name: run_shell
#
# total 8
# -rwxr-xr-x@ 1 zhengjie  staff  119 Mar 12 21:48 view_date_time.sh
#
# ================================== Ai Message ==================================
#
# 现在我找到了正确的脚本路径，让我执行它来获取当前时间和星期几。
# Tool Calls:
#   run_shell (call_e39ac1cfe8c9492583cf3ff5)
#  Call ID: call_e39ac1cfe8c9492583cf3ff5
#   Args:
#     command: /Users/zhengjie/Documents/learn-langchain/examples/skills/date-time-viewer/scripts/view_date_time.sh
# ================================= Tool Message =================================
# Name: run_shell
#
# 当前日期和时间：
# 2026年03月12日 Thursday 21:51:02
#
# ================================== Ai Message ==================================
#
# 当前时间是：2026年03月12日，星期四，21:51:02。
